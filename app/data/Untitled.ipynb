# %%
# !ls EOD/
# Out:
# ABBV.pkd  AGIO.pkd  AZN.pkd   EXEL.pkd	LLY.pkd   PFE.pkd   SNY.pkd   XLRN.pkd
# ADXS.pkd  AMGN.pkd  BMY.pkd   INCY.pkd	MOR.pkd   RARE.pkd  SPPI.pkd
# AGEN.pkd  AVEO.pkd  CLVS.pkd  KPTI.pkd	MYGN.pkd  SGEN.pkd  VSTM.pkd

# %%
# !ls News/
# Out:
# ABBV.pkd  AGIO.pkd  AZN.pkd   EXEL.pkd	LLY.pkd  RARE.pkd  VSTM.pkd
# ADXS.pkd  AMGN.pkd  BMY.pkd   INCY.pkd	MOR.pkd  SNY.pkd   XLRN.pkd
# AGEN.pkd  AVEO.pkd  CLVS.pkd  KPTI.pkd	PFE.pkd  SPPI.pkd

# %%
# !ls
# Out:
# df_dates.pkd	  final_ncts.pkd	 News			 tickers.pkd
# dict_studies.pkd  first_study_dates.pkd  ticker_first_dates.pkd  Untitled.ipynb
# EOD		  name_tickers.pkd	 ticker_names.pkd

# %%
import dill

dill.load((open('df_dates.pkd','rb')))[:10]
# Out:
#         nct_id study_first_submitted_date results_first_submitted_date  \
# 0  NCT00002348                 1999-11-02                         None
# 1  NCT00003131                 1999-11-01                         None
# 2  NCT00003293                 1999-11-01                         None
# 3  NCT00003343                 1999-11-01                         None
# 4  NCT00003669                 1999-11-01                         None
# 5  NCT00003670                 1999-11-01                         None
# 6  NCT00003673                 1999-11-01                         None
# 7  NCT00003775                 1999-11-01                         None
# 8  NCT00003821                 1999-11-01                         None
# 9  NCT00004071                 1999-12-10                         None
#
#   disposition_first_submitted_date last_update_submitted_date  \
# 0                             None                 2020-12-16
# ...
